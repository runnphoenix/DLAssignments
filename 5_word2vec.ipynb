# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# 17005207
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))

num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.060230
# Nearest to is: colleen, ziegler, carolyn, lamiaceae, fortresses, alliaceae, maybe, bangla,
# Nearest to in: keralites, francs, gunfight, ferrari, bcg, armadillos, exciting, replicators,
# Nearest to his: men, mythic, prescribed, boles, neuroscience, cfr, environmentalism, timbers,
# Nearest to an: mishnayot, simplifications, faunas, hurrian, irreducible, ellipsis, heineken, reinforced,
# Nearest to world: malting, emphasis, lymph, folkestone, unser, headway, liberia, thematic,
# Nearest to united: tableland, senna, indianapolis, tres, laconia, severing, angus, campaign,
# Nearest to by: diego, trading, taxed, engravings, warsaw, theist, screenings, perlite,
# Nearest to people: symposium, stabilizer, popular, promoted, bathroom, graziani, hdi, auchinleck,
# Nearest to he: cleves, cheerleading, capitalistic, lining, cemac, padded, claire, handbooks,
# Nearest to and: harley, athletics, tsuburaya, campbell, harcourt, dribble, shirow, ken,
# Nearest to it: punitive, precept, azariah, channel, banach, fermenting, informative, bullock,
# Nearest to one: yin, philistine, sparse, gamba, resonate, iq, halas, buffers,
# Nearest to years: coordinate, keystone, nkvd, voluminous, karaca, purge, heritage, yeasts,
# Nearest to when: criminology, flexible, atum, clooney, electronically, lakatos, inmarsat, finished,
# Nearest to these: prophet, pearls, tenderness, randall, nicaragua, reverts, ranjit, publicacion,
# Nearest to if: dispersion, reproduces, multilingual, fairy, departmental, assuring, arabella, effecting,
# Average loss at step 2000: 4.365138
# Average loss at step 4000: 3.865410
# Average loss at step 6000: 3.791849
# Average loss at step 8000: 3.690108
# Average loss at step 10000: 3.615513
# Nearest to is: was, are, has, kosova, be, small, became, marduk,
# Nearest to in: of, on, from, at, and, with, ignores, between,
# Nearest to his: their, her, the, s, its, hsuan, castillo, regression,
# Nearest to an: the, stick, pavement, incorporeal, generalissimo, restitution, faunas, literally,
# Nearest to world: chaosium, kaifu, eidyn, navarre, boomer, abrogation, bl, thematic,
# Nearest to united: senna, indianapolis, tableland, city, sith, dandelion, parsons, tres,
# Nearest to by: was, adorno, taxed, from, into, as, through, been,
# Nearest to people: stabilizer, greco, symposium, popular, cyanides, munda, poisoning, millicent,
# Nearest to he: it, they, she, who, religiosity, also, michell, i,
# Nearest to and: or, in, habitable, balances, kolbe, american, ict, treblinka,
# Nearest to it: he, there, this, not, cabin, unguarded, also, that,
# Nearest to one: two, four, three, eight, six, seven, doppler, five,
# Nearest to years: karaca, keystone, iana, lbs, bradley, gentiles, roasted, substituting,
# Nearest to when: eilean, since, cryoprotectant, rds, finished, had, friends, atum,
# Nearest to these: many, randall, no, reflexive, herbivore, several, its, bankruptcies,
# Nearest to if: dispersion, assuring, responsiveness, totalled, subject, reproduces, arabella, multilingual,
# Average loss at step 12000: 3.606318
# Average loss at step 14000: 3.570986
# Average loss at step 16000: 3.409384
# Average loss at step 18000: 3.458228
# Average loss at step 20000: 3.536988
# Nearest to is: was, has, are, be, kosova, became, but, were,
# Nearest to in: at, from, on, with, between, ignores, scout, by,
# Nearest to his: their, her, its, boles, the, hsuan, lodge, plosive,
# Nearest to an: the, ellipsis, faunas, springfield, sloth, stick, benghazi, lieutenant,
# Nearest to world: chaosium, kaifu, archive, navarre, convenes, eidyn, marinus, hetzel,
# Nearest to united: city, senna, tableland, sith, tres, indianapolis, rhus, senate,
# Nearest to by: into, were, through, in, be, was, with, been,
# Nearest to people: men, greco, anguilla, cyanides, symposium, stabilizer, bafta, poisoning,
# Nearest to he: it, she, they, who, there, michell, cabin, religiosity,
# Nearest to and: or, but, which, however, lynx, in, since, with,
# Nearest to it: he, there, this, they, cabin, which, not, she,
# Nearest to one: four, two, seven, six, three, five, eight, nine,
# Nearest to years: months, iana, degrees, lbs, questioned, penitentiary, roasted, days,
# Nearest to when: since, where, however, if, after, rds, eilean, by,
# Nearest to these: some, many, several, all, their, such, its, they,
# Nearest to if: however, multilingual, when, but, is, assuring, laetrile, southwestern,
# Average loss at step 22000: 3.506483
# Average loss at step 24000: 3.492474
# Average loss at step 26000: 3.485106
# Average loss at step 28000: 3.478359
# Average loss at step 30000: 3.505603
# Nearest to is: was, are, has, became, be, were, maybe, does,
# Nearest to in: at, ignores, within, of, during, on, and, hermeticism,
# Nearest to his: their, her, its, the, s, boles, krahn, hsuan,
# Nearest to an: sloth, driftwood, kafka, stick, springfield, whiz, ufo, faunas,
# Nearest to world: archive, convenes, navarre, kaifu, chaosium, city, myung, vp,
# Nearest to united: city, senna, sith, thinner, senate, rhus, tableland, tres,
# Nearest to by: neglects, with, been, was, were, sole, through, when,
# Nearest to people: men, bafta, agile, greco, children, munda, inclination, atomists,
# Nearest to he: it, she, they, who, there, religiosity, brad, but,
# Nearest to and: or, but, in, who, s, marketshare, xe, westernmost,
# Nearest to it: he, there, this, they, she, which, not, michell,
# Nearest to one: two, seven, four, six, five, eight, three, nine,
# Nearest to years: months, days, degrees, year, iana, times, lbs, people,
# Nearest to when: if, where, while, after, before, however, during, was,
# Nearest to these: some, many, several, such, they, their, all, other,
# Nearest to if: when, however, multilingual, unprepared, say, is, during, but,
# Average loss at step 32000: 3.499779
# Average loss at step 34000: 3.498813
# Average loss at step 36000: 3.452849
# Average loss at step 38000: 3.298071
# Average loss at step 40000: 3.432658
# Nearest to is: was, are, has, be, if, haliotis, became, flick,
# Nearest to in: of, at, ignores, and, from, finer, orbis, on,
# Nearest to his: her, their, its, s, the, krahn, hsuan, bodyguards,
# Nearest to an: vincent, springfield, nasrallah, kubitzki, skyview, extremophiles, stick, binyamin,
# Nearest to world: navarre, archive, convenes, myung, chaosium, mdma, gait, cathar,
# Nearest to united: city, senate, thinner, federal, senna, tableland, rhus, tres,
# Nearest to by: jonathan, when, with, for, cip, be, convincing, as,
# Nearest to people: men, hefner, children, writers, inclination, bafta, elektra, generalizes,
# Nearest to he: she, it, they, who, there, ardennes, this, michell,
# Nearest to and: or, but, like, in, inconsistency, kolbe, fra, strau,
# Nearest to it: he, she, there, this, they, which, not, often,
# Nearest to one: seven, eight, four, six, two, nine, five, three,
# Nearest to years: months, days, degrees, times, year, deserved, iana, penitentiary,
# Nearest to when: if, while, where, before, after, during, however, by,
# Nearest to these: some, many, several, such, they, their, both, those,
# Nearest to if: when, is, however, accomplishing, where, multilingual, in, for,
# Average loss at step 42000: 3.436334
# Average loss at step 44000: 3.453609
# Average loss at step 46000: 3.450950
# Average loss at step 48000: 3.357640
# Average loss at step 50000: 3.382817
# Nearest to is: was, are, has, became, be, if, contains, although,
# Nearest to in: of, from, on, between, during, since, across, and,
# Nearest to his: her, their, its, the, my, your, lodge, hsuan,
# Nearest to an: faunas, springfield, sloth, vincent, stick, the, literally, ufo,
# Nearest to world: navarre, archive, cathar, chaosium, myung, durian, bl, mdma,
# Nearest to united: senate, city, thinner, teaser, federal, tres, tableland, rhus,
# Nearest to by: neglects, was, through, with, excitotoxins, been, under, in,
# Nearest to people: men, children, jews, years, hefner, women, doctrines, elektra,
# Nearest to he: she, it, they, who, there, michell, ardennes, this,
# Nearest to and: or, but, of, zia, shipyard, in, injunction, bender,
# Nearest to it: he, she, there, this, they, then, michell, generally,
# Nearest to one: six, two, seven, four, eight, nine, five, three,
# Nearest to years: days, months, times, degrees, year, people, addictions, mi,
# Nearest to when: if, before, while, after, during, where, until, because,
# Nearest to these: some, many, such, those, several, both, they, their,
# Nearest to if: when, where, though, is, for, however, multilingual, before,
# Average loss at step 52000: 3.438687
# Average loss at step 54000: 3.425389
# Average loss at step 56000: 3.442630
# Average loss at step 58000: 3.397835
# Average loss at step 60000: 3.393155
# Nearest to is: was, are, has, seems, be, became, although, does,
# Nearest to in: within, among, since, across, during, including, of, yod,
# Nearest to his: her, their, its, my, macroeconomic, hsuan, your, the,
# Nearest to an: sloth, ellipsis, faunas, sunnis, frye, bailiwick, literally, benghazi,
# Nearest to world: myung, cathar, handset, gait, chaosium, bl, hypertalk, mdma,
# Nearest to united: senate, teaser, federal, thinner, rhus, senna, tres, ussr,
# Nearest to by: neglects, through, was, excitotoxins, be, when, sole, taxed,
# Nearest to people: men, women, children, americans, years, jews, anguilla, christians,
# Nearest to he: she, it, they, there, who, we, later, eventually,
# Nearest to and: or, but, than, bender, although, kolbe, however, airframe,
# Nearest to it: he, she, there, this, they, that, michell, diverging,
# Nearest to one: four, six, seven, eight, two, five, three, nine,
# Nearest to years: days, months, times, degrees, year, centuries, miles, people,
# Nearest to when: if, before, after, while, because, where, during, until,
# Nearest to these: many, some, several, such, those, both, they, their,
# Nearest to if: when, where, though, since, before, while, because, szko,
# Average loss at step 62000: 3.246601
# Average loss at step 64000: 3.258162
# Average loss at step 66000: 3.402740
# Average loss at step 68000: 3.393715
# Average loss at step 70000: 3.359032
# Nearest to is: was, has, are, be, became, seems, kosova, does,
# Nearest to in: within, on, during, between, silurian, spiracles, muse, until,
# Nearest to his: her, their, its, my, your, krahn, the, hsuan,
# Nearest to an: sloth, the, ellipsis, another, bailiwick, springfield, faunas, sunnis,
# Nearest to world: handset, cathar, fuselage, gait, zealand, durian, archive, navarre,
# Nearest to united: teaser, senate, federal, thinner, rhus, eu, ussr, tres,
# Nearest to by: through, using, newly, be, in, with, from, moria,
# Nearest to people: men, women, children, americans, jews, christians, anguilla, those,
# Nearest to he: she, it, they, there, who, we, finally, ardennes,
# Nearest to and: or, but, shipyard, while, than, stately, including, briggs,
# Nearest to it: he, she, this, there, they, still, ju, which,
# Nearest to one: two, six, seven, four, eight, five, three, nine,
# Nearest to years: days, months, year, degrees, times, centuries, miles, mi,
# Nearest to when: if, before, where, while, after, because, though, was,
# Nearest to these: many, some, such, several, those, their, the, various,
# Nearest to if: when, though, where, while, before, without, since, because,
# Average loss at step 72000: 3.377360
# Average loss at step 74000: 3.348351
# Average loss at step 76000: 3.317667
# Average loss at step 78000: 3.349362
# Average loss at step 80000: 3.379201
# Nearest to is: was, has, are, became, maybe, does, although, includes,
# Nearest to in: within, during, until, on, spiracles, at, scout, since,
# Nearest to his: her, their, its, my, your, the, krahn, our,
# Nearest to an: ellipsis, sloth, faunas, sunnis, bailiwick, rao, benghazi, turkestan,
# Nearest to world: cathar, gait, zealand, fuselage, u, kaifu, varna, navarre,
# Nearest to united: teaser, federal, senate, rhus, city, thinner, eu, ussr,
# Nearest to by: newly, through, neglects, and, vivien, banco, jock, using,
# Nearest to people: men, children, women, americans, jews, christians, man, anguilla,
# Nearest to he: she, it, they, there, who, we, ardennes, religiosity,
# Nearest to and: or, habitable, but, including, shipyard, aitken, than, while,
# Nearest to it: he, she, there, this, they, still, we, itself,
# Nearest to one: seven, six, two, eight, three, four, five, nine,
# Nearest to years: days, months, year, times, centuries, degrees, minutes, hours,
# Nearest to when: before, if, after, though, where, during, while, because,
# Nearest to these: several, many, those, various, some, such, both, different,
# Nearest to if: when, though, before, since, where, until, because, without,
# Average loss at step 82000: 3.410223
# Average loss at step 84000: 3.411447
# Average loss at step 86000: 3.393259
# Average loss at step 88000: 3.352180
# Average loss at step 90000: 3.367238
# Nearest to is: was, are, has, although, contains, does, makes, becomes,
# Nearest to in: during, within, millionaire, belzec, of, under, at, with,
# Nearest to his: her, their, its, your, my, our, the, macroeconomic,
# Nearest to an: ellipsis, sloth, benghazi, another, vincent, faunas, nasrallah, binyamin,
# Nearest to world: cathar, handset, kaifu, fuselage, punctuation, gait, istat, varna,
# Nearest to united: teaser, federal, senate, rhus, ussr, city, thinner, constitution,
# Nearest to by: when, through, with, newly, banco, without, using, neglects,
# Nearest to people: women, children, men, christians, jews, americans, man, writers,
# Nearest to he: she, it, they, there, who, we, but, michell,
# Nearest to and: or, but, shipyard, habitable, while, flawless, including, encrypting,
# Nearest to it: he, she, there, this, they, itself, still, which,
# Nearest to one: seven, four, two, eight, six, three, five, nine,
# Nearest to years: days, months, centuries, year, times, degrees, decades, hours,
# Nearest to when: if, before, after, while, where, until, during, because,
# Nearest to these: several, some, many, various, such, are, those, both,
# Nearest to if: when, where, though, since, before, because, until, without,
# Average loss at step 92000: 3.396184
# Average loss at step 94000: 3.257151
# Average loss at step 96000: 3.357509
# Average loss at step 98000: 3.242480
# Average loss at step 100000: 3.356179
# Nearest to is: was, has, became, when, be, are, becomes, does,
# Nearest to in: within, during, on, from, among, silurian, until, across,
# Nearest to his: her, their, its, my, your, the, our, s,
# Nearest to an: another, ellipsis, nasrallah, mallory, sloth, rao, faunas, benghazi,
# Nearest to world: cathar, varna, doubleday, u, zealand, navarre, gait, hitchhiker,
# Nearest to united: senate, teaser, federal, constitution, ussr, davids, eu, rhus,
# Nearest to by: when, neglects, newly, banco, through, without, with, using,
# Nearest to people: children, women, men, americans, christians, jews, students, man,
# Nearest to he: she, it, they, there, who, we, ardennes, michell,
# Nearest to and: or, but, while, however, habitable, although, when, of,
# Nearest to it: he, she, there, this, they, which, never, diverging,
# Nearest to one: two, seven, four, five, eight, six, three, zero,
# Nearest to years: days, months, year, times, degrees, centuries, hours, decades,
# Nearest to when: if, before, while, after, during, although, because, though,
# Nearest to these: several, many, some, those, various, all, certain, their,
# Nearest to if: when, though, where, before, because, since, should, did,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
  global data_index
  batch = np.ndarray(shape=(batch_size-skip_window*2, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size-skip_window*2, 1), dtype=np.int32)

  for i in range(skip_window, batch_size - skip_window):
    batch_per_label = np.ndarray(shape=(2 * skip_window), dtype=np.int32)
    labels[i-skip_window,0] = data[data_index + i]
    for j in range(skip_window):
      batch_per_label[2*j] = data[data_index+i-j-1]
      batch_per_label[2*j+1] = data[data_index+i+j+1]
    batch[i-skip_window] = batch_per_label
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window))
    for i in range(8-skip_window*2):
        print('    batch:', [reverse_dictionary[bi] for bi in batch[i]])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8-skip_window*2)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: ['anarchism', 'as']
#     batch: ['as', 'term']
#     batch: ['term', 'abuse']
#     batch: ['abuse', 'used']
#     batch: ['used', 'early']
#     batch: ['early', 'class']
#     labels: ['originated', 'a', 'of', 'first', 'against', 'working']
#
# with skip_window = 2:
#     batch: ['first', 'against', 'abuse', 'early']
#     batch: ['against', 'working', 'used', 'class']
#     batch: ['working', 'radicals', 'early', 'including']
#     batch: ['radicals', 'the', 'class', 'diggers']
#     labels: ['used', 'early', 'class', 'including']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))

num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size-2*skip_window, skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size-2*skip_window, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_mean(embeds, 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# 136
# Average loss at step 0: 7.218812
# Nearest to most: ize, sanger, barracuda, agents, revolutionize, rumelia, freudian, channel,
# Nearest to so: stanislaw, tortoise, imperfections, nitro, fixture, statewide, winner, broadleaf,
# Nearest to during: internals, epicurus, rossini, awkward, options, demonstrators, gotland, carrion,
# Nearest to been: pea, bestial, lian, hetfield, frightening, sevilla, lethe, ana,
# Nearest to can: tabulation, rommel, faceless, murdoc, syncopated, labiodental, adolescence, mobilized,
# Nearest to over: shaftesbury, antikythera, carefree, tutsis, arrian, legates, authoritarian, triangulation,
# Nearest to world: guest, wallets, furioso, gurmukhi, coupland, lica, leftist, fogo,
# Nearest to s: endanger, complaint, inland, carotenoids, desylva, versace, presentations, persephone,
# Nearest to and: scantily, metastability, escarpment, stacey, gallon, ausw, poorly, submarines,
# Nearest to were: continent, damien, hadrons, palatal, falsifiable, cmt, mba, locative,
# Nearest to will: television, saguinus, hornets, roadside, oas, barbera, fittings, neil,
# Nearest to time: bucaram, toon, approaching, plea, bake, onions, citeaux, lead,
# Nearest to not: autopilot, summons, nave, bopp, commoner, textual, homo, kilograms,
# Nearest to six: clanking, baptise, pleated, actuated, racketeering, phyllis, nevada, disgust,
# Nearest to seven: victorian, hereford, fuji, aristocrats, stockhausen, poetics, contrasting, slav,
# Nearest to eight: kitt, thames, paladins, testimony, mississippi, szl, surgeon, stratofortress,
# 252136
# Average loss at step 2000: 3.812763
# 504136
# Average loss at step 4000: 3.333216
# 756136
# Average loss at step 6000: 3.174600
# 1008136
# Average loss at step 8000: 3.071473
# 1260136
# Average loss at step 10000: 2.977531
# Nearest to most: mandalay, lfheim, pen, freudian, ize, neodymium, memorize, ner,
# Nearest to so: nitro, imperfections, stanislaw, brutus, lollards, milieu, appealed, statewide,
# Nearest to during: in, internals, courtesan, hale, porters, eostre, throughout, hoplite,
# Nearest to been: was, bestial, footnotes, wiki, ostensible, had, conservatoire, explosive,
# Nearest to can: could, would, may, must, should, moluccas, might, will,
# Nearest to over: shuttlecock, mutilated, shaftesbury, authoritarian, dagny, hybridized, antikythera, coloureds,
# Nearest to world: guest, product, bullies, gurmukhi, belarusian, roman, aba, avram,
# Nearest to s: converging, bulwer, gordie, palais, salinger, wright, versace, diaries,
# Nearest to and: amerindians, redacted, speed, crippling, gallon, or, harbour, pistol,
# Nearest to were: are, have, muller, appearance, had, was, noise, smuts,
# Nearest to will: could, would, should, must, bakelite, television, can, melanesia,
# Nearest to time: plea, dry, encryption, blowfish, celebrating, cursor, lead, foundational,
# Nearest to not: summons, still, also, kilograms, they, autopilot, colder, normans,
# Nearest to six: nine, eight, four, five, seven, three, zero, two,
# Nearest to seven: eight, nine, four, five, six, three, zero, monks,
# Nearest to eight: nine, five, six, seven, four, zero, three, two,
# 1512136
# Average loss at step 12000: 3.025727
# 1764136
# Average loss at step 14000: 2.995035
# 2016136
# Average loss at step 16000: 2.984464
# 2268136
# Average loss at step 18000: 2.985692
# 2520136
# Average loss at step 20000: 2.845893
# Nearest to most: mandalay, more, troppo, decoction, lfheim, some, neodymium, brandt,
# Nearest to so: nitro, imperfections, milieu, structures, jello, poodle, stanislaw, lollards,
# Nearest to during: in, throughout, after, internals, hale, before, porters, courtesan,
# Nearest to been: be, bestial, wiki, was, footnotes, fcc, hartley, commonly,
# Nearest to can: could, must, may, would, will, should, might, cannot,
# Nearest to over: shuttlecock, authoritarian, shaftesbury, transvaal, mutilated, hybridized, miggins, coloureds,
# Nearest to world: guest, aba, product, belarusian, wallets, avram, roman, kareem,
# Nearest to s: diaries, fumimaro, bulwer, reusable, grotius, ingrained, whose, versace,
# Nearest to and: but, amerindians, or, gallon, frontal, including, lenition, chemotherapy,
# Nearest to were: are, have, was, had, muller, be, noise, janus,
# Nearest to will: would, could, can, should, must, may, might, shall,
# Nearest to time: plea, way, dry, blowfish, encryption, cursor, necromancer, dieppe,
# Nearest to not: still, summons, colder, jameson, they, kilograms, often, paged,
# Nearest to six: eight, four, nine, five, seven, three, zero, two,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to eight: six, seven, nine, four, five, zero, three, two,
# 2772136
# Average loss at step 22000: 2.939203
# 3024136
# Average loss at step 24000: 2.924416
# 3276136
# Average loss at step 26000: 2.876571
# 3528136
# Average loss at step 28000: 2.866741
# 3780136
# Average loss at step 30000: 2.883144
# Nearest to most: mandalay, more, beginning, modena, troppo, kanal, barracuda, brandt,
# Nearest to so: milieu, imperfections, nitro, poodle, nexgen, vents, lollards, thus,
# Nearest to during: after, in, throughout, before, hale, beyond, internals, when,
# Nearest to been: be, bestial, was, wiki, become, fcc, ostensible, footnotes,
# Nearest to can: may, could, must, will, would, should, might, cannot,
# Nearest to over: shuttlecock, transvaal, shaftesbury, schema, authoritarian, coloureds, hybridized, adults,
# Nearest to world: guest, avram, samoan, product, flowering, aba, gurmukhi, archaeoastronomy,
# Nearest to s: isbn, converging, bangor, whose, puzo, roy, bitches, packet,
# Nearest to and: but, including, consoles, astrometric, amerindians, gallon, sugarcane, or,
# Nearest to were: are, have, was, had, muller, be, noise, janus,
# Nearest to will: would, could, can, must, should, may, might, shall,
# Nearest to time: plea, way, blowfish, line, stratton, rise, endpoint, dieppe,
# Nearest to not: still, summons, cannot, jameson, generally, enable, simply, now,
# Nearest to six: five, four, eight, three, seven, nine, zero, two,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# 4032136
# Average loss at step 32000: 2.853069
# 4284136
# Average loss at step 34000: 2.688688
# 4536136
# Average loss at step 36000: 2.832853
# 4788136
# Average loss at step 38000: 2.837827
# 5040136
# Average loss at step 40000: 2.789312
# Nearest to most: more, mandalay, some, many, militaristic, decoction, modena, kanal,
# Nearest to so: thus, therefore, nitro, lollards, milieu, imperfections, jackal, ejected,
# Nearest to during: in, after, throughout, before, since, despite, hale, salomon,
# Nearest to been: be, become, was, bestial, were, ostensible, wiki, hartley,
# Nearest to can: may, could, will, must, would, should, might, cannot,
# Nearest to over: shuttlecock, shaftesbury, schema, coloureds, hybridized, transvaal, jitsu, antikythera,
# Nearest to world: flowering, kareem, guest, shortly, avram, samoan, wallets, mcc,
# Nearest to s: isbn, diaries, puzo, marys, chocolates, whose, palais, bangor,
# Nearest to and: anhui, consoles, amerindians, sugarcane, including, or, fellowship, cedric,
# Nearest to were: are, have, had, was, been, muller, be, splicing,
# Nearest to will: would, can, may, could, must, should, might, shall,
# Nearest to time: plea, stratton, cursor, endpoint, extent, credit, dry, blowfish,
# Nearest to not: still, almost, occasionally, generally, cannot, rarely, simply, usually,
# Nearest to six: four, five, seven, eight, three, nine, two, zero,
# Nearest to seven: six, eight, nine, four, five, three, two, zero,
# Nearest to eight: nine, five, seven, six, four, three, zero, two,
# 5292136
# Average loss at step 42000: 2.809908
# 5544136
# Average loss at step 44000: 2.837649
# 5796136
# Average loss at step 46000: 2.822816
# 6048136
# Average loss at step 48000: 2.796078
# 6300136
# Average loss at step 50000: 2.752267
# Nearest to most: more, many, mandalay, some, militaristic, beginning, kanal, less,
# Nearest to so: thus, therefore, lollards, jackal, imperfections, milieu, nitro, reducible,
# Nearest to during: in, after, throughout, before, since, despite, hale, beyond,
# Nearest to been: be, was, become, bestial, footnotes, instinct, wiki, ostensible,
# Nearest to can: may, could, will, must, would, should, might, cannot,
# Nearest to over: shuttlecock, shaftesbury, alternates, tagging, schema, jitsu, hybridized, wiesbaden,
# Nearest to world: kareem, flowering, avram, shortly, mcc, samoan, guest, absolutism,
# Nearest to s: whose, isbn, entrepreneurship, puzo, bitches, our, vents, magnate,
# Nearest to and: or, frisbee, sugarcane, incur, trioxide, but, indies, harbour,
# Nearest to were: are, have, was, had, became, muller, homily, noise,
# Nearest to will: would, can, may, could, must, should, might, shall,
# Nearest to time: plea, stratton, rise, endpoint, way, extent, blowfish, muentzer,
# Nearest to not: occasionally, cannot, still, almost, anil, never, polygons, rarely,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to seven: four, five, eight, six, nine, three, zero, two,
# Nearest to eight: nine, four, five, seven, six, three, zero, two,
# 6552136
# Average loss at step 52000: 2.738250
# 6804136
# Average loss at step 54000: 2.783876
# 7056136
# Average loss at step 56000: 2.747533
# 7308136
# Average loss at step 58000: 2.758801
# 7560136
# Average loss at step 60000: 2.643027
# Nearest to most: more, some, many, mandalay, beginning, modena, less, militaristic,
# Nearest to so: thus, therefore, lollards, requires, bhumi, jackal, imperfections, persecutions,
# Nearest to during: after, throughout, in, before, despite, since, under, at,
# Nearest to been: be, become, was, bestial, were, grown, footnotes, thabit,
# Nearest to can: may, could, must, would, will, should, might, cannot,
# Nearest to over: shuttlecock, across, tagging, alternates, schema, antikythera, shaftesbury, jitsu,
# Nearest to world: kareem, flowering, aba, absolutism, mcc, unintentional, unwise, avram,
# Nearest to s: isbn, whose, magnate, puzo, packet, bangor, gazpacho, bitches,
# Nearest to and: but, or, sugarcane, however, consoles, amerindians, ordnance, bumper,
# Nearest to were: are, have, had, was, became, muller, malays, been,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to time: plea, way, rise, blowfish, clutches, stratton, round, extent,
# Nearest to not: never, actually, occasionally, rarely, still, anil, cannot, almost,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# 7812136
# Average loss at step 62000: 2.726753
# 8064136
# Average loss at step 64000: 2.731299
# 8316136
# Average loss at step 66000: 2.689623
# 8568136
# Average loss at step 68000: 2.648040
# 8820136
# Average loss at step 70000: 2.622659
# Nearest to most: more, many, some, mandalay, beginning, less, militaristic, modena,
# Nearest to so: thus, therefore, lollards, requires, biosphere, imperfections, pointer, jackal,
# Nearest to during: in, after, throughout, before, since, despite, under, colloquially,
# Nearest to been: be, become, was, bestial, were, grown, ostensible, thabit,
# Nearest to can: may, could, must, will, should, would, cannot, might,
# Nearest to over: across, shuttlecock, wiesbaden, schema, tagging, jitsu, antikythera, sugarcubes,
# Nearest to world: kareem, mcc, flowering, samoan, geologically, shortly, crusade, aba,
# Nearest to s: isbn, whose, mel, palais, hazael, neil, kinetics, puzo,
# Nearest to and: bumper, or, but, vermin, however, concerning, destroyer, traced,
# Nearest to were: are, have, had, was, became, been, be, muller,
# Nearest to will: would, can, may, must, should, could, might, cannot,
# Nearest to time: plea, rise, extent, cursor, blowfish, way, clutches, muentzer,
# Nearest to not: still, never, occasionally, anil, actually, rarely, almost, ploughing,
# Nearest to six: five, seven, four, eight, nine, three, two, zero,
# Nearest to seven: eight, six, five, nine, four, three, two, zero,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# 9072136
# Average loss at step 72000: 2.661593
# 9324136
# Average loss at step 74000: 2.698360
# 9576136
# Average loss at step 76000: 2.660551
# 9828136
# Average loss at step 78000: 2.600898
# 10080136
# Average loss at step 80000: 2.708257
# Nearest to most: more, many, some, beginning, mandalay, less, modena, planetfall,
# Nearest to so: therefore, thus, requires, jackal, biosphere, imperfections, lollards, rebbe,
# Nearest to during: after, in, throughout, before, since, colloquially, under, despite,
# Nearest to been: be, become, grown, was, bestial, were, thabit, ostensible,
# Nearest to can: may, could, must, would, will, should, might, cannot,
# Nearest to over: across, alternates, antikythera, shuttlecock, schema, tagging, jitsu, wiesbaden,
# Nearest to world: mcc, kareem, flowering, painless, avram, mix, zeit, fogo,
# Nearest to s: whose, isbn, palais, mel, magnate, religionfacts, gary, plebeian,
# Nearest to and: but, however, anhui, bumper, chamorro, trioxide, or, amerindians,
# Nearest to were: are, have, had, was, been, became, trolls, those,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to time: plea, extent, blowfish, cursor, way, endpoint, stratton, rise,
# Nearest to not: never, still, occasionally, rarely, actually, anil, paged, hardly,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to seven: six, five, eight, four, nine, three, two, zero,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# 10332136
# Average loss at step 82000: 2.716750
# 10584136
# Average loss at step 84000: 2.590743
# 10836136
# Average loss at step 86000: 2.666861
# 11088136
# Average loss at step 88000: 2.638863
# 11340136
# Average loss at step 90000: 2.662609
# Nearest to most: more, some, many, beginning, less, mandalay, planetfall, especially,
# Nearest to so: therefore, thus, requires, lollards, imperfections, puts, pointer, fj,
# Nearest to during: after, in, before, since, throughout, despite, under, beyond,
# Nearest to been: be, become, grown, bestial, were, was, thabit, gone,
# Nearest to can: could, may, must, will, would, should, cannot, might,
# Nearest to over: across, bernoulli, shuttlecock, alternates, tagging, hilberg, jitsu, baronet,
# Nearest to world: kareem, mcc, painless, flowering, mix, traverses, dialogues, avram,
# Nearest to s: whose, isbn, entrepreneurship, magnate, argonne, gary, religionfacts, puzo,
# Nearest to and: but, or, including, alleviated, sugarcane, incur, consoles, bumper,
# Nearest to were: are, have, had, was, those, be, been, being,
# Nearest to will: would, can, could, should, must, may, might, cannot,
# Nearest to time: plea, extent, rise, cursor, endpoint, stratton, intolerant, way,
# Nearest to not: occasionally, never, rarely, strongly, actually, still, polygons, cannot,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# 11592136
# Average loss at step 92000: 2.675327
# 11844136
# Average loss at step 94000: 2.576424
# 12096136
# Average loss at step 96000: 2.656875
# 12348136
# Average loss at step 98000: 2.625746
# 12600136
# Average loss at step 100000: 2.614765
# Nearest to most: more, some, many, beginning, less, mandalay, especially, planetfall,
# Nearest to so: therefore, requires, imperfections, thus, puts, palatalization, pointer, boot,
# Nearest to during: after, in, before, throughout, since, despite, under, at,
# Nearest to been: be, become, were, grown, gone, bestial, thabit, come,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to over: across, shuttlecock, baronet, hilberg, alternates, hybridized, bernoulli, jitsu,
# Nearest to world: kareem, mcc, mix, oldsmobile, avram, geologically, shortly, unwise,
# Nearest to s: whose, neil, isbn, gary, palais, puzo, magnate, kinetics,
# Nearest to and: or, sugarcane, aunts, but, bumper, chamorro, consoles, including,
# Nearest to were: are, have, had, was, been, be, being, tend,
# Nearest to will: would, can, could, should, may, must, might, cannot,
# Nearest to time: plea, extent, rise, endpoint, swnts, way, blowfish, cursor,
# Nearest to not: occasionally, rarely, never, actually, always, still, strongly, absolutely,
# Nearest to six: seven, four, eight, five, nine, three, zero, two,
# Nearest to seven: nine, five, six, eight, four, three, zero, two,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
